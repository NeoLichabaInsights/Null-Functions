-- %%
-- Create a table with columns and their respective datatypes and constraints (if any)
CREATE TABLE Employees (
    employee_id int PRIMARY KEY, -- employee_id must be unique
    name VARCHAR(20), -- person's name is limited to 20 characters
    department VARCHAR(10), -- department name is limited to 10 characters
    salary DECIMAL(10,2) 
);

-- Insert values into the table
INSERT INTO Employees (employee_id, name, department, salary)
VALUES
(1, 'Alice', 'HR', 5000),
(2, 'Bob', 'IT', NULL),
(3, 'Charlie', 'NULL', 7000),
(4, 'Dana', 'Finance', NULL);

-- Run query to check contents of the table are accurately loaded
SELECT *
FROM Employees;

-- Q1. Show all employees with their salary. If salary is NULL, display 0

SELECT employee_id, name,
       IFNULL(salary,0) AS salary_with_default
FROM employees;
